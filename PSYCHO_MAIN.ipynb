# %% [markdown]
# <h1 align="center">СОЗДАНИЕ ВСПОМОГАТЕЛЬНОГО ПО ДЛЯ ЛАБОРАТОРИИ КОГНИТИВНЫХ ИССЛЕДОВАНИЙ ЮФУ</h1>

# %% [markdown]
# ![sfedu-V-13-L_eng.png](attachment:sfedu-V-13-L_eng.png)

# %% [markdown]
# ### В современном мире психологические тесты широко используются для оценки личности, способностей и склонностей человека. Однако, обработка результатов тестирования может быть сложной и трудоемкой задачей.
#
# ### В этом проекте мы предлагаем использовать методы и технологии data science для автоматизации и упрощения процесса обработки результатов психологического тестирования. Наша цель - создать инновационную систему, которая позволит быстро и точно анализировать данные тестирования, выявлять скрытые закономерности и делать выводы о личности тестируемого.

# %% [markdown]
# ![imgonline-com-ua-Resize-7IC1duWDvxZjT.png](attachment:imgonline-com-ua-Resize-7IC1duWDvxZjT.png)

# %% [markdown]
# ![imgonline-com-ua-Resize-kVDLg0XaqR6z3.png](attachment:imgonline-com-ua-Resize-kVDLg0XaqR6z3.png)

# %% [markdown]
# ### Идеальным выбором языка программирования для проекта будет `Python` - он поддерживает большое количество различных библиотек для data-science, самые популярные - `Pandas` и `matplotlib`. **Воспользуемся ими.**

# %% [markdown]
# ### <font color='green'>Подключаем библиотеки:</font>

# %%
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sbn
import numpy as np

# %% [markdown]
# ### <font color='green'>Подключим базы данных и выполним предподготовку данных:</font>

# %%
data_frame1 = pd.read_csv("C:/Users/Макар/Desktop/Тип-восприятия_1.csv") #88x48
data_frame2 = pd.read_csv("C:/Users/Макар/Desktop/Креативность_1.csv") #88x50
data_frame1['Укажите пожалуйста свой пол'] = data_frame1['Укажите пожалуйста свой пол'].map({'Женский': 0, 'Мужской': 1})
data_frame1 = data_frame1.replace({'Нет': 0, 'Да': 1})
data_frame2['Укажи пожалуйста свой пол'] = data_frame2['Укажи пожалуйста свой пол'].map({'Женский': 0, 'Мужской': 1})
data_frame2 = data_frame2.replace({'Зактрудняюсь ответить': 0, 'Не согласен': 1, 'Согласен от части': 2, 'Согласен': 3 })
data_frame1 = data_frame1.drop(data_frame1.columns[range(42)], axis=1)
data_frame2 = data_frame2.drop(data_frame2.columns[[0,1]], axis=1)
l1 = len(data_frame1.index)
l2 = len(data_frame2.index)
res1 = pd.DataFrame(index=range(l1),columns=['ВИЗУАЛЬНЫЙ', 'АУДИАЛЬНЫЙ', 'КИНЕСТИЧЕСКИЙ'])
res2 = pd.DataFrame(index=range(l2),columns=['ЛЮБОЗНАТЕЛЬНОСТЬ','ВООБРАЖЕНИЕ','СЛОЖНОСТЬ','СКЛОННОСТЬ К РИСКУ'])
res1 = res1.replace(np.nan, 0)
res2 = res2.replace(np.nan, 0)

# %% [markdown]
# ### <font color='green'>Реализуем алгоритм обработки результатов респондетов для 1 методики:</font>

# %%
for i in range(l1):
    
    if data_frame1.iloc[i, 0]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 1]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 2]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 3]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 4]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 5]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 6]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 7]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 8]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 9]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 10]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 11]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 12]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 13]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 14]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 15]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 16]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 17]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 18]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 19]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 20]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 21]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 22]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 23]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 24]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 25]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 26]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 27]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 28]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 29]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 30]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 31]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 32]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 33]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 34]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 35]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 36]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 37]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 38]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 39]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 40]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 41]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 42]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 43]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 44]:res1.iloc[i, 0]+=1
    if data_frame1.iloc[i, 45]:res1.iloc[i, 1]+=1
    if data_frame1.iloc[i, 46]:res1.iloc[i, 2]+=1
    if data_frame1.iloc[i, 47]:res1.iloc[i, 1]+=1

# %% [markdown]
# ### <font color='green'>Алгоритм для 2-ой методики:</font>

# %%
for i in range(l2):
    
    if data_frame2.iloc[i, 0] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 0] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 0] == 3: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 1] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 1] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 1] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 2] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 2] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 2] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 3] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 3] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 3] == 1: res2.iloc[i, 2]+=2
    
    if data_frame2.iloc[i, 4] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 4] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 4] == 1: res2.iloc[i, 3]+=2
    
    if data_frame2.iloc[i, 6] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 6] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 6] == 3: res2.iloc[i, 2]+=2
    
    if data_frame2.iloc[i, 7] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 7] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 7] == 1: res2.iloc[i, 3]+=2
    
    if data_frame2.iloc[i, 8] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 8] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 8] == 1: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 9] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 9] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 9] == 1: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 10] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 10] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 10] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 11] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 11] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 11] == 3: res2.iloc[i, 0]+=2
    
    if data_frame2.iloc[i, 12] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 12] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 12] == 3: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 13] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 13] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 13] == 1: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 14] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 14] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 14] == 3: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 15] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 15] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 15] == 3: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 16] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 16] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 16] == 1: res2.iloc[i, 2]+=2
    
    if data_frame2.iloc[i, 17] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 17] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 17] == 3: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 18] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 18] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 18] == 3: res2.iloc[i, 0]+=2
    
    if data_frame2.iloc[i, 19] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 19] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 19] == 1: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 20] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 20] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 20] == 3: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 21] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 21] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 21] == 1: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 22] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 22] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 22] == 3: res2.iloc[i, 1]+=2
    
    if data_frame2.iloc[i, 23] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 23] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 23] == 1: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 24] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 24] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 24] == 3: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 25] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 25] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 25] == 3: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 26] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 26] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 26] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 27] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 27] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 27] == 1: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 28] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 28] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 28] == 1: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 29] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 29] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 29] == 3: res2.iloc[i, 1]+=2
    
    if data_frame2.iloc[i, 30] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 30] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 30] == 3: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 31] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 31] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 31] == 1: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 32] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 32] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 32] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 33] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 33] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 33] == 1: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 34] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 34] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 34] == 3: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 35] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 35] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 35] == 3: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 36] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 36] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 36] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 37] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 37] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 37] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 38] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 38] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 38] == 1: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 39] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 39] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 39] == 3: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 40] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 40] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 40] == 1: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 41] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 41] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 41] == 3: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 42] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 42] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 42] == 3: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 43] == 0: res2.iloc[i, 3]-=1
    elif data_frame2.iloc[i, 43] == 2: res2.iloc[i, 3]+=1
    elif data_frame2.iloc[i, 43] == 3: res2.iloc[i, 3]+=2
        
    if data_frame2.iloc[i, 44] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 44] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 44] == 3: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 45] == 0: res2.iloc[i, 1]-=1
    elif data_frame2.iloc[i, 45] == 2: res2.iloc[i, 1]+=1
    elif data_frame2.iloc[i, 45] == 3: res2.iloc[i, 1]+=2
        
    if data_frame2.iloc[i, 46] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 46] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 46] == 3: res2.iloc[i, 0]+=2
        
    if data_frame2.iloc[i, 47] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 47] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 47] == 1: res2.iloc[i, 2]+=2
        
    if data_frame2.iloc[i, 48] == 0: res2.iloc[i, 0]-=1
    elif data_frame2.iloc[i, 48] == 2: res2.iloc[i, 0]+=1
    elif data_frame2.iloc[i, 48] == 3: res2.iloc[i, 0]+=2
    
    if data_frame2.iloc[i, 49] == 0: res2.iloc[i, 2]-=1
    elif data_frame2.iloc[i, 49] == 2: res2.iloc[i, 2]+=1
    elif data_frame2.iloc[i, 49] == 3: res2.iloc[i, 2]+=2

# %% [markdown]
# ### <font color='green'>Найдём ключевые факторы и заполним дата-фреймы с финальным результатами:</font>

# %%
f_res1 = pd.DataFrame(index=range(l1),columns=['канал_восприятия'])
f_res1 = f_res1.replace(np.nan, 0)
f_res2 = pd.DataFrame(index=range(l1),columns=['фактор_креативности'])
f_res2 = f_res2.replace(np.nan, 0)

counter1_vis = counter1_aud = counter1_cin = 0
counter2_lyub = counter2_img = counter2_com = counter2_risk = 0

for i in range(l1):
    A = []
    A.append(res1.iloc[i, 0])
    A.append(res1.iloc[i, 1])
    A.append(res1.iloc[i, 2])
    if A.index(max(A)) == 0: 
        f_res1.iloc[i, 0] = "ВИЗУАЛЬНЫЙ"
        counter1_vis += 1
    elif A.index(max(A)) == 1:
        f_res1.iloc[i, 0] = "АУДИАЛЬНЫЙ"
        counter1_aud += 1
    else:
        f_res1.iloc[i, 0] = "КИНЕСТЕТИЧЕСКИЙ"
        counter1_cin += 1
        
for i in range(l2):
    A = []
    A.append(res2.iloc[i, 0])
    A.append(res2.iloc[i, 1])
    A.append(res2.iloc[i, 2])
    A.append(res2.iloc[i, 3])
    if A.index(max(A)) == 0:
        f_res2.iloc[i, 0] = "ЛЮБОЗНАТЕЛЬНОСТЬ"
        counter2_lyub += 1
    elif A.index(max(A)) == 1:
        f_res2.iloc[i, 0] = "ВООБРАЖЕНИЕ"
        counter2_img += 1
    elif A.index(max(A)) == 2:
        f_res2.iloc[i, 0] = "СЛОЖНОСТЬ"
        counter2_com += 1
    else:
        f_res2.iloc[i, 0] = "СКЛОННОСТЬ К РИСКУ"
        counter2_risk += 1

# %% [markdown]
# ### Найдём результаты тестирования конкретного пользователя по его ID:

# %%
n = int(input())
print(f_res1.loc[[n]])
print(res2.loc[[n]])
# Out:
# 75
#    канал_восприятия
# 75       ВИЗУАЛЬНЫЙ
#     ЛЮБОЗНАТЕЛЬНОСТЬ  ВООБРАЖЕНИЕ  СЛОЖНОСТЬ  СКЛОННОСТЬ К РИСКУ
# 75                10            7          4                  12

# %% [markdown]
# ## Посторим круговые диаграммы, отображающие основные типы восприятия и факторы креативности всех распондентов:

# %%
labels = 'Любознательность', 'Воображениe', 'Сложность', 'Склонность к риску'
sizes = [counter2_lyub,  counter2_img, counter2_com, counter2_risk]

fig, ax = mp.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x15f0da36050>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'Любознательность'),
#   Text(-0.7985950875185377, 0.7564693557516122, 'Воображениe'),
#   Text(-1.0821193122757982, -0.19752922315382598, 'Сложность'),
#   Text(0.44377877675766364, -1.006509015011526, 'Склонность к риску')])

# %%
labels = 'ВИЗУАЛЬНЫЙ', 'АУДИАЛЬНЫЙ', 'КИНЕСТЕТИЧЕСКИЙ'
sizes = [counter1_vis,   counter1_aud, counter1_cin]
fig, ax = mp.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x15f0daa88b0>,
# ...
#  [Text(0.3323544988795668, 1.0485897610955928, 'ВИЗУАЛЬНЫЙ'),
#   Text(-0.5152494479285563, -0.9718631623892934, 'АУДИАЛЬНЫЙ'),
#   Text(1.0821192775994926, -0.1975294131200525, 'КИНЕСТЕТИЧЕСКИЙ')])

# %% [markdown]
# ### Построим корреляционную тепловую матрицу (heatmap)

# %%
result = pd.concat((res1, res2), axis=1, join='inner')
tmp = result.corr()
tmp.head()
sbn.heatmap(tmp)
# Out:
# <AxesSubplot: >
